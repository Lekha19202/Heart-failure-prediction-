# %% [markdown]
# ### In this dataset will be used to predict if a pepson will be affected by a heart disease or not. The data set contains 15 coulmns that can be used to generate insights for a possiblity of heart disease.

# %% [markdown]
# Dataset discription
#
# Attributes
#
# Age: age of the patient [years]
#
# Sex: sex of the patient [M: Male, F: Female]
#
# Height: height of the patient
#
# Smoke: does the person smoke[Y: Yes, N: No]
#
# ChestPainType: chest pain type [TA: Typical Angina, ATA: Atypical Angina, NAP: Non-Anginal Pain, ASY: Asymptomatic]
#
# RestingBP: resting blood pressure [mm Hg]
#
# Cholesterol: serum cholesterol [mm/dl]
#
# FastingBS: fasting blood sugar
#
# ATA: maximum heart ATA![image-2.png]
#
# RestingECG: resting electrocardiogram results [Normal: Normal, ST:abnormality ]
#
# MaxHR: maximum heart rate
#
# ExerciseAngina: exercise-induced angina [Y: Yes, N: No]
#
# Oldpeak: oldpeak = ST [Numeric value measured in depression]
#
# ST_Slope: the slope of the peak exercise ST segment [Up: upsloping, Flat: flat, Down: downsloping]
#
# HeartDisease: output class [1: heart disease, 0: Normal]

# %%
import pandas as pd 
hr = pd.read_csv("heart.csv")

# %%
import matplotlib.pyplot as plt

# %%
hr.head(20)
# Out:
#     Age  Height Sex Smoke ChestPainType  RestingBP     ATA  Cholesterol  \
# 0    40    62.1   M    no           ATA        140   6.475          289
# 1    49    74.7   F   yes           NAP        160  10.125          180
# 2    37    69.7   M    no           ATA        130   9.550          283
# 3    48    71.0   F    no           ASY        138     NaN          214
# 4    54    56.9   M    no           NAP        150   4.800          195
# 5    39    58.7   M    no           NAP        120   6.225          339
# 6    45    63.3   F    no           ATA        130   4.950          237
# 7    54    70.4   M    no           ATA        110   7.325          208
# 8    37    70.5   M    no           ASY        140   8.875          207
# 9    48    59.2   F    no           ATA        120     NaN          284
# 10   37    76.4   F    no           NAP        130  11.500          211
# 11   58    71.7   M    no           ATA        136     NaN          164
# ...

# %% [markdown]
# ## Data Cleaning

# %%
#data cleaning 1

hr.isnull().sum()
# Out:
# Age               0
# Height            0
# Sex               0
# Smoke             0
# ChestPainType     0
# RestingBP         0
# ATA               4
# Cholesterol       0
# FastingBS         0
# RestingECG        4
# MaxHR             0
# ExerciseAngina    3
# Oldpeak           0
# ST_Slope          0
# HeartDisease      3
# dtype: int64

# %%
#data cleaning 2
hr.Sex.replace( { "M" : "Male", "F" :"Female"} , inplace = True)

hr.head(5)
# Out:
#    Age  Height     Sex Smoke ChestPainType  RestingBP     ATA  Cholesterol  \
# 0   40    62.1    Male    no           ATA        140   6.475          289
# 1   49    74.7  Female   yes           NAP        160  10.125          180
# 2   37    69.7    Male    no           ATA        130   9.550          283
# 3   48    71.0  Female    no           ASY        138     NaN          214
# 4   54    56.9    Male    no           NAP        150   4.800          195
#
#    FastingBS RestingECG  MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0          0     Normal    172              N      0.0       Up           0.0
# 1          0     Normal    156              N      1.0     Flat           1.0
# 2          0         ST     98              N      0.0       Up           0.0
# 3          0        NaN    108              Y      1.5     Flat           NaN
# 4          0     Normal    122            NaN      0.0       Up           0.0

# %%
#datacleaning 3
hr['ATA'].fillna(hr['ATA'].mean(),inplace = True )

hr.head(10)
# Out:
#    Age  Height     Sex Smoke ChestPainType  RestingBP        ATA  Cholesterol  \
# 0   40    62.1    Male    no           ATA        140   6.475000          289
# 1   49    74.7  Female   yes           NAP        160  10.125000          180
# 2   37    69.7    Male    no           ATA        130   9.550000          283
# 3   48    71.0  Female    no           ASY        138   7.827551          214
# 4   54    56.9    Male    no           NAP        150   4.800000          195
# 5   39    58.7    Male    no           NAP        120   6.225000          339
# 6   45    63.3  Female    no           ATA        130   4.950000          237
# 7   54    70.4    Male    no           ATA        110   7.325000          208
# 8   37    70.5    Male    no           ASY        140   8.875000          207
# 9   48    59.2  Female    no           ATA        120   7.827551          284
#
#    FastingBS RestingECG  MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
#datacleaning 4
hr["ATA"]=hr["ATA"].astype('int64')

hr.head(20)
# Out:
#     Age  Height     Sex Smoke ChestPainType  RestingBP  ATA  Cholesterol  \
# 0    40    62.1    Male    no           ATA        140    6          289
# 1    49    74.7  Female   yes           NAP        160   10          180
# 2    37    69.7    Male    no           ATA        130    9          283
# 3    48    71.0  Female    no           ASY        138    7          214
# 4    54    56.9    Male    no           NAP        150    4          195
# 5    39    58.7    Male    no           NAP        120    6          339
# 6    45    63.3  Female    no           ATA        130    4          237
# 7    54    70.4    Male    no           ATA        110    7          208
# 8    37    70.5    Male    no           ASY        140    8          207
# 9    48    59.2  Female    no           ATA        120    7          284
# 10   37    76.4  Female    no           NAP        130   11          211
# 11   58    71.7    Male    no           ATA        136    7          164
# ...

# %%
print(hr.dtypes)
# Out:
# Age                 int64
# Height            float64
# Sex                object
# Smoke              object
# ChestPainType      object
# RestingBP           int64
# ATA                 int64
# Cholesterol         int64
# FastingBS           int64
# RestingECG         object
# MaxHR               int64
# ExerciseAngina     object
# Oldpeak           float64
# ST_Slope           object
# HeartDisease      float64
# dtype: object

# %%
#data cleaning 5
print("before cleaning rows count:",len(hr))
hr.dropna(inplace=True)
print("after cleaning rows count:",len(hr))
# Out:
# before cleaning rows count: 918
# after cleaning rows count: 909

# %%
hr.isnull().sum()
# Out:
# Age               0
# Height            0
# Sex               0
# Smoke             0
# ChestPainType     0
# RestingBP         0
# ATA               0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
#datacleaning 6
hr.drop(hr.loc[hr['Cholesterol']==0].index, inplace=True)
len(hr)
# Out:
# 737

# %% [markdown]
# ## Show/Apply Summary Statistics

# %%
#to know the rows and columns count
print(hr.shape)
# Out:
# (737, 15)

# %%
#min and max of colestrol
print(hr['Cholesterol'].min())
print(hr['Cholesterol'].max())
print(hr['Cholesterol'].mean())
# Out:
# 85
# 603
# 244.98778833107193

# %%
#mean age of people having a HeartDisease
df_Age = hr.loc[(hr['HeartDisease'] == 1) & 
                         (hr['Age'] > 18)]
print(df_Age['Age'].mean())
print(df_Age['Age'].median())
print(df_Age['Age'].std())
# Out:
# 55.99145299145299
# 57.0
# 8.754912801878625

# %%
#Covariance It computes the covariance of columns pairwise while excluding the NA/null values. 
#covariance is a measure of the relationship between two random variables. 
#The metric evaluates how much what extent – the variables change together. 
#In other words, it is essentially a measure of the variance between two variables.

df_corr=hr.Smoke.replace( { "no" : 0, "yes" :1} ,inplace=True)
df_corr

# %%
df_corr=hr.iloc[: ,[0,3,-1]]
df_corr.cov()
# Out:
#                     Age     Smoke  HeartDisease
# Age           90.449428 -0.126176      1.446043
# Smoke         -0.126176  0.093689      0.005881
# HeartDisease   1.446043  0.005881      0.249775

# %%
# calculating z-score
from scipy.stats import zscore
df_zscore=hr.iloc[:,[5,6,7,8,-1]]
df_zscore.apply(zscore)
# Out:
#      RestingBP       ATA  Cholesterol  FastingBS  HeartDisease
# 0     0.401428 -0.520590     0.742400  -0.451938     -0.953586
# 1     1.556198  1.017185    -1.096217  -0.451938      1.048673
# 2    -0.175958  0.632741     0.641192  -0.451938     -0.953586
# 5    -0.753343 -0.520590     1.585802  -0.451938     -0.953586
# 7    -1.330728 -0.136146    -0.623912  -0.451938     -0.953586
# ..         ...       ...          ...        ...           ...
# 913  -1.330728  0.248297     0.320699  -0.451938      1.048673
# 914   0.632382  0.632741    -0.876932   2.212691      1.048673
# 915  -0.175958  0.248297    -1.922751  -0.451938      1.048673
# 916  -0.175958 -0.520590    -0.151606  -0.451938      1.048673
# 917   0.285951  0.632741    -1.180557  -0.451938     -0.953586
#
# [737 rows x 5 columns]

# %%
#Statictical data for the entite datset
print(hr.describe())
# Out:
#               Age      Height       Smoke   RestingBP         ATA  \
# count  737.000000  737.000000  737.000000  737.000000  737.000000
# mean    52.959294   64.672456    0.104478  133.047490    7.354138
# std      9.510490    7.008779    0.306087   17.331226    2.602927
# min     28.000000   45.300000    0.000000   92.000000    0.000000
# 25%     46.000000   59.900000    0.000000  120.000000    6.000000
# 50%     54.000000   65.300000    0.000000  130.000000    7.000000
# 75%     59.000000   69.400000    0.000000  140.000000    9.000000
# max     77.000000   81.800000    1.000000  200.000000   14.000000
#
#        Cholesterol   FastingBS       MaxHR     Oldpeak  HeartDisease
# count   737.000000  737.000000  737.000000  737.000000    737.000000
# mean    244.987788    0.169607  140.321574    0.904478      0.476255
# std      59.323964    0.375542   24.531335    1.075616      0.499775
# min      85.000000    0.000000   69.000000   -0.100000      0.000000
# ...

# %% [markdown]
# ## Analysis & Visualizations

# %%
#chart 1
#What is the rage of colestrol level of all the records in the data set?
#Seaborn is a Python data visualization library based on matplotlib.
#It provides a high-level interface for drawing attractive and informative statistical graphics
import seaborn as sns 
plt.figure(figsize = (30, 30))
sns.displot(hr['Cholesterol'])

plt.show()

# %% [markdown]
# This graph shows the rage of colestrol level of all the entries in the data set

# %%
#chart 2
#What factors influence the most and their featur importance in accordance to heart failure?
#A heatmap is a graphical representation of data that uses a system of color-coding to represent different values
plt.figure(figsize=(8,5))
sns.heatmap(hr.corr(), annot=True, cmap='RdYlBu')
# Out:
# <AxesSubplot:>

# %% [markdown]
# The purpose of this map is to show the range of values in the data set and give a colour feel to it for better understanding.From the heat map we can see the darker colurs(dark orange and red) shows the high values and the lighter colours(dark blue and light blue show low values of the data set.

# %%
#chart 3
#What role do variables like chest pain type, resting BP (ECG), Age and Sex slope play in understanding the pathophysiology of heart failure?

fig, ax = plt.subplots(2,2,figsize=(16,10))
# Age the relationship between Age and HeartDisease

sns.kdeplot(
    ax = ax[0][0],
    data = hr,
    x = 'Age',
    hue = 'HeartDisease',
    fill = True,
    linewidth = 0
)
ax[0][0].grid(False)
ax[0][0].set_ylabel('')
#sns.move_legend(ax[0][0], loc='upper left') # move legend location

# Sex
sns.countplot(
    ax = ax[0][1],
    data = hr,
    x = 'Sex',
    hue = 'HeartDisease'
)
ax[0][1].grid(False)
ax[0][1].set_xticklabels(['female','male'])
ax[0][1].set_ylabel('')

# ChestPainType
sns.stripplot(
    ax = ax[1][0],
    data=hr,
    x='ChestPainType',
    y='Age',
    hue='HeartDisease'
)
ax[1][0].set_xticklabels(['TA', 'ATA', 'NAP', 'ASY'])
ax[1][0].set_ylabel('')
ax[1][0].grid(False)

# RestingBP
sns.boxenplot(
    ax = ax[1][1],
    data = hr,
    y = 'RestingBP',
    x = 'HeartDisease'
)
ax[1][1].set_ylabel('')
ax[1][1].set_xlabel('RestingBP')
ax[1][1].grid(False)


plt.show()

# %%
#chart 4
#Different type of chest pains and their correlation with heart disease ? 
sns.countplot(x = "ChestPainType", hue = "HeartDisease", data= hr)
# Out:
# <AxesSubplot:xlabel='ChestPainType', ylabel='count'>
